# %%
import pydot
from IPython.display import Image

# Create a new graph
graph = pydot.Dot(graph_type='digraph')

# Define nodes
nodes = [
    'Start',
    'Check DATA_DIR',
    'Create DATA_DIR',
    'Initialize label dictionary',
    'Calculate number_of_classes',
    'Set dataset_size',
    'Initialize video capture',
    'Loop through each class',
    'Check class directory',
    'Create class directory',
    "Print 'Collecting data for class'",
    'Set done flag to False',
    'Loop until done is True',
    'Read frame from video capture',
    'Display frame with text',
    'Wait for key press',
    "Check if 'Q' key is pressed",
    'Break from loop',
    "Check if 'X' key is pressed",
    'Set done flag to True',
    'Check if counter reaches dataset_size',
    'Check if done is True',
    'Save frame as image',
    'Increment counter',
    'Release video capture',
    'Close all windows',
    'End'
]

# Add nodes to the graph
for node in nodes:
    graph.add_node(pydot.Node(node))

# Define edges
edges = [
    ('Start', 'Check DATA_DIR'),
    ('Check DATA_DIR', 'Create DATA_DIR'),
    ('Check DATA_DIR', 'Initialize label dictionary'),
    ('Initialize label dictionary', 'Calculate number_of_classes'),
    ('Calculate number_of_classes', 'Set dataset_size'),
    ('Set dataset_size', 'Initialize video capture'),
    ('Initialize video capture', 'Loop through each class'),
    ('Loop through each class', 'Check class directory'),
    ('Check class directory', 'Create class directory'),
    ('Create class directory', "Print 'Collecting data for class'"),
    ("Print 'Collecting data for class'", 'Set done flag to False'),
    ('Set done flag to False', 'Loop until done is True'),
    ('Loop until done is True', 'Read frame from video capture'),
    ('Read frame from video capture', 'Display frame with text'),
    ('Display frame with text', 'Wait for key press'),
    ('Wait for key press', "Check if 'Q' key is pressed"),
    ("Check if 'Q' key is pressed", 'Break from loop'),
    ('Wait for key press', "Check if 'X' key is pressed"),
    ("Check if 'X' key is pressed", 'Set done flag to True'),
    ('Check if done is True', 'Check if counter reaches dataset_size'),
    ('Check if counter reaches dataset_size', 'Check if done is True'),
    ('Check if done is True', 'Save frame as image'),
    ('Save frame as image', 'Increment counter'),
    ('Increment counter', 'Loop until done is True'),
    ('Loop until done is True', 'Read frame from video capture'),
    ('Read frame from video capture', 'Display frame with text'),
    ('Display frame with text', 'Wait for key press'),
    ('Wait for key press', "Check if 'Q' key is pressed"),
    ("Check if 'Q' key is pressed", 'Break from loop'),
    ('Wait for key press', "Check if 'X' key is pressed"),
    ("Check if 'X' key is pressed", 'Set done flag to True'),
    ('Check if done is True', 'Check if counter reaches dataset_size'),
    ('Check if counter reaches dataset_size', 'Check if done is True'),
    ('Check if done is True', 'Save frame as image'),
    ('Save frame as image', 'Increment counter'),
    ('Increment counter', 'Loop until done is True'),
    ('Loop until done is True', 'Read frame from video capture'),
    ('Read frame from video capture', 'Display frame with text'),
    ('Display frame with text', 'Wait for key press'),
    ('Wait for key press', "Check if 'Q' key is pressed"),
    ("Check if 'Q' key is pressed", 'Break from loop'),
    ('Wait for key press', "Check if 'X' key is pressed"),
    ("Check if 'X' key is pressed", 'Set done flag to True'),
    ('Check if done is True', 'Check if counter reaches dataset_size'),
    ('Check if counter reaches dataset_size', 'Check if done is True'),
    ('Check if done is True', 'Save frame as image'),
    ('Save frame as image', 'Increment counter'),
    ('Increment counter', 'Loop until done is True'),
    ('Loop until done is True', 'Read frame from video capture'),
    ('Read frame from video capture', 'Close all windows'),
    ('Close all windows', 'End')
]

# Add edges to the graph
for edge in edges:
    graph.add_edge(pydot.Edge(edge[0], edge[1]))

# Save the graph as a DOT file
graph.write_png('flowchart.png')

# Display the graph image
Image(filename='flowchart.png')
